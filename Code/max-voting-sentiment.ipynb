# %%
# import deepmatcher as dm
import itertools
import os
import pandas as pd
# import model_discovery
from tqdm.notebook import tqdm
from sklearn.model_selection import train_test_split

# from model_discovery import utils, l2lsh
import re

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

import nltk
from sklearn.feature_extraction.text import CountVectorizer
from nltk.corpus import stopwords
from wordcloud import WordCloud,STOPWORDS
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from bs4 import BeautifulSoup
import re,string,unicodedata
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score,f1_score
from sklearn.model_selection import train_test_split
from string import punctuation
from nltk import pos_tag
from nltk.corpus import wordnet


import keras
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow import keras 
from keras import backend as K
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.optimizers import Adam
from keras.layers import LSTM,Dense,Bidirectional,Input
from keras.models import Model
import torch
import transformers

# %%
def strip_html(text):
    soup = BeautifulSoup(text, "html.parser")
    return soup.get_text()

#Removing the square brackets
def remove_between_square_brackets(text):
    return re.sub('\[[^]]*\]', '', text)
# Removing URL's
def remove_between_square_brackets(text):
    return re.sub(r'http\S+', '', text)
#Removing the stopwords from text
def remove_stopwords(text):
    final_text = []
    for i in text.split():
        if i.strip().lower() not in stop and i.strip().lower().isalpha():
            final_text.append(i.strip().lower())
    return " ".join(final_text)
#Removing the noisy text
def denoise_text(text):
    text = strip_html(text)
    text = remove_between_square_brackets(text)
    text = remove_stopwords(text)
    return text

def fast_encode(texts, tokenizer_fuc, chunk_size=256, maxlen=400):

    tokenizer_fuc.enable_truncation(max_length=maxlen)
    tokenizer_fuc.enable_padding(length=maxlen)
    all_ids = []
    for i in range(0, len(texts), chunk_size):
        text_chunk = texts[i:i+chunk_size].tolist()
        encs = tokenizer_fuc.encode_batch(text_chunk)
        all_ids.extend([enc.ids for enc in encs])
    
    return np.array(all_ids)

# %%
def build_model(transformer, max_len=400):
    
    input_word_ids = Input(shape=(max_len,), dtype=tf.int32, name="input_word_ids")
    sequence_output = transformer(input_word_ids)[0]
    cls_token = sequence_output[:, 0, :]
    out = Dense(1, activation='sigmoid')(cls_token)
    
    model = Model(inputs=input_word_ids, outputs=out)
    model.compile(Adam(lr=2e-5), loss='binary_crossentropy', metrics=['accuracy'])
    
    return model

stop = set(stopwords.words('english'))
punctuation = list(string.punctuation)
stop.update(punctuation)

from tokenizers import BertWordPieceTokenizer
# First load the real tokenizer
tokenizer_ = transformers.DistilBertTokenizer.from_pretrained('distilbert-base-uncased' , lower = True)
# Save the loaded tokenizer locally
tokenizer_.save_pretrained('.')
# Reload it with the huggingface tokenizers library
fast_tokenizer = BertWordPieceTokenizer('vocab.txt', lowercase=True)
bert_model = transformers.TFDistilBertModel.from_pretrained('distilbert-base-uncased')
# Out:
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/226k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/455k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/483 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/347M [00:00<?, ?B/s]
# 2022-04-10 23:59:40.566165: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-10 23:59:40.567312: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-10 23:59:40.567998: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-10 23:59:40.568869: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-04-10 23:59:40.569866: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-10 23:59:40.570566: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-10 23:59:40.571234: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-10 23:59:45.545320: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-10 23:59:45.546280: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-10 23:59:45.547023: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-04-10 23:59:45.547615: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 14973 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# 2022-04-10 23:59:45.882185: W tensorflow/python/util/util.cc:348] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# Some layers from the model checkpoint at distilbert-base-uncased were not used when initializing TFDistilBertModel: ['activation_13', 'vocab_layer_norm', 'vocab_projector', 'vocab_transform']
# - This IS expected if you are initializing TFDistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFDistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFDistilBertModel were initialized from the model checkpoint at distilbert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFDistilBertModel for predictions without further training.

# %%
result_df=pd.read_csv('../input/model-search-dataset/Sentiment_serving-train.csv')
result_df
# Out:
#               Source            Target       JSD  Adaptivity       L2D  \
# 0            Movie_2   Tweets_hatred_5  0.149241    6.714286  0.089254
# 1   Financial_News_1   Tweets_hatred_5  0.490986    0.857143  0.159169
# 2            Movie_1   Tweets_hatred_5  0.147102    6.142857  0.088685
# 3           Tweets_1   Tweets_hatred_5  0.081495    7.000000  0.053569
# 4   Financial_News_2   Tweets_hatred_5  0.505265    4.285714  0.163838
# 5           Tweets_2   Tweets_hatred_5  0.084933    7.000000  0.055481
# 6           Tweets_1          Tweets_2  0.014739    7.000000  0.019774
# 7   Financial_News_1          Tweets_2  0.527444    0.000000  0.152935
# 8   Financial_News_2          Tweets_2  0.542546    3.000000  0.156966
# 9            Movie_1          Tweets_2  0.131600    5.857143  0.079972
# 10           Movie_2          Tweets_2  0.135734    6.714286  0.080345
# 11   Tweets_hatred_5          Tweets_2  0.084933    7.000000  0.055481
# 12          Tweets_2          Tweets_1  0.014739    7.000000  0.019774
# 13  Financial_News_1          Tweets_1  0.528589    0.857143  0.152178
# 14  Financial_News_2          Tweets_1  0.544714    4.428571  0.157176
# 15           Movie_1          Tweets_1  0.131713    6.428571  0.080624
# 16           Movie_2          Tweets_1  0.135876    6.714286  0.081145
# 17   Tweets_hatred_5          Tweets_1  0.081495    7.000000  0.053569
# 18  Financial_News_1           Movie_2  0.483421    0.000000  0.191573
# 19          Tweets_1           Movie_2  0.135876    6.714286  0.081145
# 20          Tweets_2           Movie_2  0.135734    6.714286  0.080345
# 21           Movie_1           Movie_2  0.001441    7.000000  0.006493
# 22  Financial_News_2           Movie_2  0.496676    4.571429  0.201040
# 23   Tweets_hatred_5           Movie_2  0.149241    6.714286  0.089254
# 24           Movie_2           Movie_1  0.001441    7.000000  0.006493
# 25  Financial_News_1           Movie_1  0.485331    1.714286  0.192901
# 26          Tweets_2           Movie_1  0.131600    5.714286  0.079972
# 27          Tweets_1           Movie_1  0.131713    6.571429  0.080624
# 28  Financial_News_2           Movie_1  0.496569    5.428571  0.201324
# 29   Tweets_hatred_5           Movie_1  0.147102    6.857143  0.088685
# 30  Financial_News_1  Financial_News_2  0.019859    0.857143  0.021655
# 31          Tweets_1  Financial_News_2  0.544714    4.714286  0.157176
# 32          Tweets_2  Financial_News_2  0.542546    2.857143  0.156966
# 33           Movie_1  Financial_News_2  0.496569    5.428571  0.201324
# 34           Movie_2  Financial_News_2  0.496676    4.285714  0.201040
# 35   Tweets_hatred_5  Financial_News_2  0.505265    3.714286  0.163838
# 36          Tweets_1  Financial_News_1  0.528589    0.857143  0.152178
# 37          Tweets_2  Financial_News_1  0.527444    0.000000  0.152935
# 38  Financial_News_2  Financial_News_1  0.019859    0.857143  0.021655
# 39           Movie_1  Financial_News_1  0.485331    1.714286  0.192901
# 40           Movie_2  Financial_News_1  0.483421    0.000000  0.191573
# 41   Tweets_hatred_5  Financial_News_1  0.490986    0.857143  0.159169
#
#     Source Accuracy  Serving Accuracy  Finetune Accuracy
# 0         80.800003         92.666668           6.400000
# 1         96.799999         83.133334          91.000003
# 2         81.599998         77.466667          93.599999
# 3         69.400001         73.000002          59.399998
# 4         91.600001         71.533334          89.999998
# 5         68.599999         67.199999          52.600002
# 6         69.400001         68.466669          69.000000
# 7         96.799999         62.333333          67.000002
# 8         91.600001         60.399997          64.999998
# 9         81.599998         60.200000          64.999998
# 10        80.800003         52.133334          69.400001
# 11        93.199998         51.933336          52.999997
# 12        68.599999         80.400002          72.600001
# 13        96.799999         61.133331          68.400002
# 14        91.600001         60.066664          66.799998
# 15        81.599998         58.666664          62.199998
# 16        80.800003         50.400001          67.799997
# 17        93.199998         49.533334          49.399999
# 18        96.799999         85.399997          82.400000
# 19        69.400001         82.200003          81.599998
# 20        68.599999         81.933331          82.999998
# 21        81.599998         80.733335          79.600000
# 22        91.600001         67.000002          53.399998
# 23        93.199998         49.200001          67.799997
# 24        80.800003         81.933331          85.799998
# 25        96.799999         79.466665          85.600001
# 26        68.599999         78.266668          85.399997
# 27        69.400001         77.333331          85.000002
# 28        91.600001         64.866668          74.000001
# 29        93.199998         49.733335          63.200003
# 30        96.799999         92.133331          96.399999
# 31        69.400001         89.200002          95.200002
# 32        68.599999         87.733334          95.800000
# 33        81.599998         75.199997          93.000001
# 34        80.800003         71.200001          95.800000
# 35        93.199998         70.800000          79.200000
# 36        69.400001         93.800002          97.399998
# 37        68.599999         90.733331          93.400002
# 38        91.600001         85.600001          95.999998
# 39        81.599998         73.533332          91.799998
# 40        80.800003         73.000002          95.200002
# 41        93.199998         72.266668          89.600003

# %%
datasets = ['../input/imbd-data-1/Movie_1.csv', '../input/imbd-data-1/Movie_2.csv', 
            '../input/financial-news-data-2/Financial_News_2.csv', '../input/financial-news-data-2/Financial_News_1.csv',
            '../input/tweets-data-4/Tweets_1.csv','../input/tweets-data-4/Tweets_2.csv',
           '../input/tweets-hatred-data-5/Tweets_hatred_5.csv']

# %%
arr_target= np.asarray(list(set(result_df['Target'].values)))
arr_target
# Out:
# array(['Tweets_1', 'Movie_2', 'Financial_News_1', 'Movie_1', 'Tweets_2',
#        'Financial_News_2', 'Tweets_hatred_5'], dtype='<U16')

# %%
df_target_dic={}
for d in datasets:
    f_name = re.search('input/(.*).csv', d).group(1).split('/')[1]
    df_target_dic[f_name]=d
df_target_dic
# Out:
# {'Movie_1': '../input/imbd-data-1/Movie_1.csv',
#  'Movie_2': '../input/imbd-data-1/Movie_2.csv',
#  'Financial_News_2': '../input/financial-news-data-2/Financial_News_2.csv',
#  'Financial_News_1': '../input/financial-news-data-2/Financial_News_1.csv',
#  'Tweets_1': '../input/tweets-data-4/Tweets_1.csv',
#  'Tweets_2': '../input/tweets-data-4/Tweets_2.csv',
#  'Tweets_hatred_5': '../input/tweets-hatred-data-5/Tweets_hatred_5.csv'}

# %%
arr_model_already_trained=['../input/model-search-dataset/Financial_News_1_trained_model',
                           '../input/model-search-dataset/Financial_News_2_trained_model',
                           '../input/model-search-dataset/Movie_1_trained_model',
                           '../input/model-search-dataset/Movie_2_trained_model',
                           '../input/model-search-dataset/Tweets_1_trained_model',
                           '../input/model-search-dataset/Tweets_2_trained_model',
                           '../input/model-search-dataset/Tweets_hatred_5_trained_model'
                          ]

# %%
a=[0.9,0.2,0.5,0.6]

def sum_threshold(x):
    if x>=2:
        return 1
    else:
        return 0

def func_threshold(x):
    if x>=0.5:
        return 1
    else:
        return 0
output_list = [func_threshold(i) for i in a]
output_list
# Out:
# [1, 0, 1, 1]

# %%
from collections import defaultdict

array1 = [1,2,3,4]  
array2 = [6,3,2,3]
array3 = [5,7,11,15]

my_dict = defaultdict(list)
my_dict[1].append(array1)
my_dict[1].append(array2)

my_dict
# Out:
# defaultdict(list, {1: [[1, 2, 3, 4], [6, 3, 2, 3]]})

# %%
metrics=['JSD','Adaptivity','L2D','Source Accuracy']
metric_dic={}
for m in metrics:
    temp_df=[]
    print("--------")
    target_dict_max_voting={}
    for target in arr_target:
        
        temp_df = result_df[result_df['Target']==target][['Source','Target',m]]
        
        if m=='Adaptivity' or m=='Source Accuracy':
            temp_df= temp_df.nlargest(3, m)
        else:
            temp_df= temp_df.nsmallest(3, m)
        print("TARGET-",target)
#         print("Data-")
#         print(temp_df)
        dict_predict_curr={}
        for src in temp_df['Source'].values:
            # Model Save
            file_name = '../input/model-search-dataset/'+src+"_trained_model"
            print(file_name)
            if file_name in arr_model_already_trained: # model is already saved
                model_src = build_model(bert_model, max_len=400)
                model_src.load_weights(file_name)
                print("")
                print("Weights Loaded-      ",file_name)
            print("Target dataset loaded-    ",target)
            
            df_target=pd.read_csv(df_target_dic[target]).sample(2000, replace=True,random_state=10)
            df_target['text']=df_target['text'].apply(denoise_text)
            x_train_target= df_target.text
            x_train_target = fast_encode(x_train_target.values, fast_tokenizer, maxlen=400)
            y_pred = model_src.predict(x_train_target) 
            output_pred = [func_threshold(i) for i in y_pred]
            dict_predict_curr[src]=output_pred
        
#         print(dict_predict_curr)
        sum_arr=[]
        for p in range(len(y_pred)):
            s=0
            for x in dict_predict_curr:
                s+=dict_predict_curr[x][p]
            sum_arr.append(s)    
        max_voted_arr = [sum_threshold(i) for i in sum_arr]
#         print("vote freq arr-", max_voted_arr)
        max_voted_model={}
        for source_model in dict_predict_curr:
            print(source_model,"-->",target)
            for i,val in enumerate(dict_predict_curr[source_model]):
                if max_voted_arr[i]==val:
                    if source_model in max_voted_model:
                        max_voted_model[source_model]+=1
                    else:
                        max_voted_model[source_model]=1
                 
        print(max_voted_model)
        
        ####
        # creating target dict
        target_dict_max_voting[target]=max_voted_model
    print(target_dict_max_voting)
    metric_dic[m]=target_dict_max_voting
print("----##----")
print(metric_dic)
# Out:
# --------
# TARGET- Tweets_1
# ../input/model-search-dataset/Tweets_2_trained_model
# /opt/conda/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Weights Loaded-       ../input/model-search-dataset/Tweets_2_trained_model
# Target dataset loaded-     Tweets_1
# 2022-04-11 00:00:01.359103: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# ../input/model-search-dataset/Tweets_hatred_5_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_hatred_5_trained_model
# Target dataset loaded-     Tweets_1
# ../input/model-search-dataset/Movie_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_1_trained_model
# Target dataset loaded-     Tweets_1
# Tweets_2 --> Tweets_1
# Tweets_hatred_5 --> Tweets_1
# Movie_1 --> Tweets_1
# {'Tweets_2': 1426, 'Tweets_hatred_5': 1588, 'Movie_1': 1879}
# TARGET- Movie_2
# ../input/model-search-dataset/Movie_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_1_trained_model
# Target dataset loaded-     Movie_2
# ../input/model-search-dataset/Tweets_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_2_trained_model
# Target dataset loaded-     Movie_2
# ../input/model-search-dataset/Tweets_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_1_trained_model
# Target dataset loaded-     Movie_2
# Movie_1 --> Movie_2
# Tweets_2 --> Movie_2
# Tweets_1 --> Movie_2
# {'Movie_1': 1763, 'Tweets_2': 1892, 'Tweets_1': 1842}
# TARGET- Financial_News_1
# ../input/model-search-dataset/Financial_News_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Financial_News_2_trained_model
# Target dataset loaded-     Financial_News_1
# ../input/model-search-dataset/Movie_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_2_trained_model
# Target dataset loaded-     Financial_News_1
# ../input/model-search-dataset/Movie_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_1_trained_model
# Target dataset loaded-     Financial_News_1
# Financial_News_2 --> Financial_News_1
# Movie_2 --> Financial_News_1
# Movie_1 --> Financial_News_1
# {'Financial_News_2': 1778, 'Movie_2': 1767, 'Movie_1': 1836}
# TARGET- Movie_1
# ../input/model-search-dataset/Movie_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_2_trained_model
# Target dataset loaded-     Movie_1
# ../input/model-search-dataset/Tweets_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_2_trained_model
# Target dataset loaded-     Movie_1
# ../input/model-search-dataset/Tweets_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_1_trained_model
# Target dataset loaded-     Movie_1
# Movie_2 --> Movie_1
# Tweets_2 --> Movie_1
# Tweets_1 --> Movie_1
# {'Movie_2': 1698, 'Tweets_2': 1882, 'Tweets_1': 1862}
# TARGET- Tweets_2
# ../input/model-search-dataset/Tweets_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_1_trained_model
# Target dataset loaded-     Tweets_2
# ../input/model-search-dataset/Tweets_hatred_5_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_hatred_5_trained_model
# Target dataset loaded-     Tweets_2
# ../input/model-search-dataset/Movie_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_1_trained_model
# Target dataset loaded-     Tweets_2
# Tweets_1 --> Tweets_2
# Tweets_hatred_5 --> Tweets_2
# Movie_1 --> Tweets_2
# {'Tweets_1': 1558, 'Tweets_hatred_5': 1604, 'Movie_1': 1832}
# TARGET- Financial_News_2
# ../input/model-search-dataset/Financial_News_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Financial_News_1_trained_model
# Target dataset loaded-     Financial_News_2
# ../input/model-search-dataset/Movie_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_1_trained_model
# Target dataset loaded-     Financial_News_2
# ../input/model-search-dataset/Movie_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_2_trained_model
# Target dataset loaded-     Financial_News_2
# Financial_News_1 --> Financial_News_2
# Movie_1 --> Financial_News_2
# Movie_2 --> Financial_News_2
# {'Financial_News_1': 1740, 'Movie_1': 1841, 'Movie_2': 1785}
# TARGET- Tweets_hatred_5
# ../input/model-search-dataset/Tweets_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_1_trained_model
# Target dataset loaded-     Tweets_hatred_5
# ../input/model-search-dataset/Tweets_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_2_trained_model
# Target dataset loaded-     Tweets_hatred_5
# ../input/model-search-dataset/Movie_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_1_trained_model
# Target dataset loaded-     Tweets_hatred_5
# Tweets_1 --> Tweets_hatred_5
# Tweets_2 --> Tweets_hatred_5
# Movie_1 --> Tweets_hatred_5
# {'Tweets_1': 1868, 'Tweets_2': 1807, 'Movie_1': 1655}
# {'Tweets_1': {'Tweets_2': 1426, 'Tweets_hatred_5': 1588, 'Movie_1': 1879}, 'Movie_2': {'Movie_1': 1763, 'Tweets_2': 1892, 'Tweets_1': 1842}, 'Financial_News_1': {'Financial_News_2': 1778, 'Movie_2': 1767, 'Movie_1': 1836}, 'Movie_1': {'Movie_2': 1698, 'Tweets_2': 1882, 'Tweets_1': 1862}, 'Tweets_2': {'Tweets_1': 1558, 'Tweets_hatred_5': 1604, 'Movie_1': 1832}, 'Financial_News_2': {'Financial_News_1': 1740, 'Movie_1': 1841, 'Movie_2': 1785}, 'Tweets_hatred_5': {'Tweets_1': 1868, 'Tweets_2': 1807, 'Movie_1': 1655}}
# --------
# TARGET- Tweets_1
# ../input/model-search-dataset/Tweets_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_2_trained_model
# Target dataset loaded-     Tweets_1
# ../input/model-search-dataset/Tweets_hatred_5_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_hatred_5_trained_model
# Target dataset loaded-     Tweets_1
# ../input/model-search-dataset/Movie_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_2_trained_model
# Target dataset loaded-     Tweets_1
# Tweets_2 --> Tweets_1
# Tweets_hatred_5 --> Tweets_1
# Movie_2 --> Tweets_1
# {'Tweets_2': 1087, 'Tweets_hatred_5': 1927, 'Movie_2': 1984}
# TARGET- Movie_2
# ../input/model-search-dataset/Movie_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_1_trained_model
# Target dataset loaded-     Movie_2
# ../input/model-search-dataset/Tweets_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_1_trained_model
# Target dataset loaded-     Movie_2
# ../input/model-search-dataset/Tweets_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_2_trained_model
# Target dataset loaded-     Movie_2
# Movie_1 --> Movie_2
# Tweets_1 --> Movie_2
# Tweets_2 --> Movie_2
# {'Movie_1': 1763, 'Tweets_1': 1842, 'Tweets_2': 1892}
# TARGET- Financial_News_1
# ../input/model-search-dataset/Movie_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_1_trained_model
# Target dataset loaded-     Financial_News_1
# ../input/model-search-dataset/Tweets_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_1_trained_model
# Target dataset loaded-     Financial_News_1
# ../input/model-search-dataset/Financial_News_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Financial_News_2_trained_model
# Target dataset loaded-     Financial_News_1
# Movie_1 --> Financial_News_1
# Tweets_1 --> Financial_News_1
# Financial_News_2 --> Financial_News_1
# {'Movie_1': 1684, 'Tweets_1': 1769, 'Financial_News_2': 1930}
# TARGET- Movie_1
# ../input/model-search-dataset/Movie_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_2_trained_model
# Target dataset loaded-     Movie_1
# ../input/model-search-dataset/Tweets_hatred_5_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_hatred_5_trained_model
# Target dataset loaded-     Movie_1
# ../input/model-search-dataset/Tweets_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_1_trained_model
# Target dataset loaded-     Movie_1
# Movie_2 --> Movie_1
# Tweets_hatred_5 --> Movie_1
# Tweets_1 --> Movie_1
# {'Movie_2': 1941, 'Tweets_hatred_5': 1271, 'Tweets_1': 1619}
# TARGET- Tweets_2
# ../input/model-search-dataset/Tweets_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_1_trained_model
# Target dataset loaded-     Tweets_2
# ../input/model-search-dataset/Tweets_hatred_5_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_hatred_5_trained_model
# Target dataset loaded-     Tweets_2
# ../input/model-search-dataset/Movie_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_2_trained_model
# Target dataset loaded-     Tweets_2
# Tweets_1 --> Tweets_2
# Tweets_hatred_5 --> Tweets_2
# Movie_2 --> Tweets_2
# {'Tweets_1': 1240, 'Tweets_hatred_5': 1922, 'Movie_2': 1977}
# TARGET- Financial_News_2
# ../input/model-search-dataset/Movie_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_1_trained_model
# Target dataset loaded-     Financial_News_2
# ../input/model-search-dataset/Tweets_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_1_trained_model
# Target dataset loaded-     Financial_News_2
# ../input/model-search-dataset/Movie_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_2_trained_model
# Target dataset loaded-     Financial_News_2
# Movie_1 --> Financial_News_2
# Tweets_1 --> Financial_News_2
# Movie_2 --> Financial_News_2
# {'Movie_1': 1872, 'Tweets_1': 1662, 'Movie_2': 1754}
# TARGET- Tweets_hatred_5
# ../input/model-search-dataset/Tweets_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_1_trained_model
# Target dataset loaded-     Tweets_hatred_5
# ../input/model-search-dataset/Tweets_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_2_trained_model
# Target dataset loaded-     Tweets_hatred_5
# ../input/model-search-dataset/Movie_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_2_trained_model
# Target dataset loaded-     Tweets_hatred_5
# Tweets_1 --> Tweets_hatred_5
# Tweets_2 --> Tweets_hatred_5
# Movie_2 --> Tweets_hatred_5
# {'Tweets_1': 1892, 'Tweets_2': 1783, 'Movie_2': 1532}
# {'Tweets_1': {'Tweets_2': 1087, 'Tweets_hatred_5': 1927, 'Movie_2': 1984}, 'Movie_2': {'Movie_1': 1763, 'Tweets_1': 1842, 'Tweets_2': 1892}, 'Financial_News_1': {'Movie_1': 1684, 'Tweets_1': 1769, 'Financial_News_2': 1930}, 'Movie_1': {'Movie_2': 1941, 'Tweets_hatred_5': 1271, 'Tweets_1': 1619}, 'Tweets_2': {'Tweets_1': 1240, 'Tweets_hatred_5': 1922, 'Movie_2': 1977}, 'Financial_News_2': {'Movie_1': 1872, 'Tweets_1': 1662, 'Movie_2': 1754}, 'Tweets_hatred_5': {'Tweets_1': 1892, 'Tweets_2': 1783, 'Movie_2': 1532}}
# --------
# TARGET- Tweets_1
# ../input/model-search-dataset/Tweets_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_2_trained_model
# Target dataset loaded-     Tweets_1
# ../input/model-search-dataset/Tweets_hatred_5_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_hatred_5_trained_model
# Target dataset loaded-     Tweets_1
# ../input/model-search-dataset/Movie_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_1_trained_model
# Target dataset loaded-     Tweets_1
# Tweets_2 --> Tweets_1
# Tweets_hatred_5 --> Tweets_1
# Movie_1 --> Tweets_1
# {'Tweets_2': 1426, 'Tweets_hatred_5': 1588, 'Movie_1': 1879}
# TARGET- Movie_2
# ../input/model-search-dataset/Movie_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_1_trained_model
# Target dataset loaded-     Movie_2
# ../input/model-search-dataset/Tweets_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_2_trained_model
# Target dataset loaded-     Movie_2
# ../input/model-search-dataset/Tweets_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_1_trained_model
# Target dataset loaded-     Movie_2
# Movie_1 --> Movie_2
# Tweets_2 --> Movie_2
# Tweets_1 --> Movie_2
# {'Movie_1': 1763, 'Tweets_2': 1892, 'Tweets_1': 1842}
# TARGET- Financial_News_1
# ../input/model-search-dataset/Financial_News_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Financial_News_2_trained_model
# Target dataset loaded-     Financial_News_1
# ../input/model-search-dataset/Tweets_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_1_trained_model
# Target dataset loaded-     Financial_News_1
# ../input/model-search-dataset/Tweets_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_2_trained_model
# Target dataset loaded-     Financial_News_1
# Financial_News_2 --> Financial_News_1
# Tweets_1 --> Financial_News_1
# Tweets_2 --> Financial_News_1
# {'Financial_News_2': 1774, 'Tweets_1': 1925, 'Tweets_2': 1883}
# TARGET- Movie_1
# ../input/model-search-dataset/Movie_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_2_trained_model
# Target dataset loaded-     Movie_1
# ../input/model-search-dataset/Tweets_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_2_trained_model
# Target dataset loaded-     Movie_1
# ../input/model-search-dataset/Tweets_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_1_trained_model
# Target dataset loaded-     Movie_1
# Movie_2 --> Movie_1
# Tweets_2 --> Movie_1
# Tweets_1 --> Movie_1
# {'Movie_2': 1698, 'Tweets_2': 1882, 'Tweets_1': 1862}
# TARGET- Tweets_2
# ../input/model-search-dataset/Tweets_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_1_trained_model
# Target dataset loaded-     Tweets_2
# ../input/model-search-dataset/Tweets_hatred_5_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_hatred_5_trained_model
# Target dataset loaded-     Tweets_2
# ../input/model-search-dataset/Movie_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_1_trained_model
# Target dataset loaded-     Tweets_2
# Tweets_1 --> Tweets_2
# Tweets_hatred_5 --> Tweets_2
# Movie_1 --> Tweets_2
# {'Tweets_1': 1558, 'Tweets_hatred_5': 1604, 'Movie_1': 1832}
# TARGET- Financial_News_2
# ../input/model-search-dataset/Financial_News_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Financial_News_1_trained_model
# Target dataset loaded-     Financial_News_2
# ../input/model-search-dataset/Tweets_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_2_trained_model
# Target dataset loaded-     Financial_News_2
# ../input/model-search-dataset/Tweets_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_1_trained_model
# Target dataset loaded-     Financial_News_2
# Financial_News_1 --> Financial_News_2
# Tweets_2 --> Financial_News_2
# Tweets_1 --> Financial_News_2
# {'Financial_News_1': 1910, 'Tweets_2': 1880, 'Tweets_1': 1927}
# TARGET- Tweets_hatred_5
# ../input/model-search-dataset/Tweets_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_1_trained_model
# Target dataset loaded-     Tweets_hatred_5
# ../input/model-search-dataset/Tweets_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_2_trained_model
# Target dataset loaded-     Tweets_hatred_5
# ../input/model-search-dataset/Movie_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_1_trained_model
# Target dataset loaded-     Tweets_hatred_5
# Tweets_1 --> Tweets_hatred_5
# Tweets_2 --> Tweets_hatred_5
# Movie_1 --> Tweets_hatred_5
# {'Tweets_1': 1868, 'Tweets_2': 1807, 'Movie_1': 1655}
# {'Tweets_1': {'Tweets_2': 1426, 'Tweets_hatred_5': 1588, 'Movie_1': 1879}, 'Movie_2': {'Movie_1': 1763, 'Tweets_2': 1892, 'Tweets_1': 1842}, 'Financial_News_1': {'Financial_News_2': 1774, 'Tweets_1': 1925, 'Tweets_2': 1883}, 'Movie_1': {'Movie_2': 1698, 'Tweets_2': 1882, 'Tweets_1': 1862}, 'Tweets_2': {'Tweets_1': 1558, 'Tweets_hatred_5': 1604, 'Movie_1': 1832}, 'Financial_News_2': {'Financial_News_1': 1910, 'Tweets_2': 1880, 'Tweets_1': 1927}, 'Tweets_hatred_5': {'Tweets_1': 1868, 'Tweets_2': 1807, 'Movie_1': 1655}}
# --------
# TARGET- Tweets_1
# ../input/model-search-dataset/Financial_News_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Financial_News_1_trained_model
# Target dataset loaded-     Tweets_1
# ../input/model-search-dataset/Tweets_hatred_5_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_hatred_5_trained_model
# Target dataset loaded-     Tweets_1
# ../input/model-search-dataset/Financial_News_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Financial_News_2_trained_model
# Target dataset loaded-     Tweets_1
# Financial_News_1 --> Tweets_1
# Tweets_hatred_5 --> Tweets_1
# Financial_News_2 --> Tweets_1
# {'Financial_News_1': 1872, 'Tweets_hatred_5': 1639, 'Financial_News_2': 1782}
# TARGET- Movie_2
# ../input/model-search-dataset/Financial_News_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Financial_News_1_trained_model
# Target dataset loaded-     Movie_2
# ../input/model-search-dataset/Tweets_hatred_5_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_hatred_5_trained_model
# Target dataset loaded-     Movie_2
# ../input/model-search-dataset/Financial_News_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Financial_News_2_trained_model
# Target dataset loaded-     Movie_2
# Financial_News_1 --> Movie_2
# Tweets_hatred_5 --> Movie_2
# Financial_News_2 --> Movie_2
# {'Financial_News_1': 1508, 'Tweets_hatred_5': 1639, 'Financial_News_2': 1994}
# TARGET- Financial_News_1
# ../input/model-search-dataset/Tweets_hatred_5_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_hatred_5_trained_model
# Target dataset loaded-     Financial_News_1
# ../input/model-search-dataset/Financial_News_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Financial_News_2_trained_model
# Target dataset loaded-     Financial_News_1
# ../input/model-search-dataset/Movie_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_1_trained_model
# Target dataset loaded-     Financial_News_1
# Tweets_hatred_5 --> Financial_News_1
# Financial_News_2 --> Financial_News_1
# Movie_1 --> Financial_News_1
# {'Tweets_hatred_5': 1687, 'Financial_News_2': 1779, 'Movie_1': 1835}
# TARGET- Movie_1
# ../input/model-search-dataset/Financial_News_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Financial_News_1_trained_model
# Target dataset loaded-     Movie_1
# ../input/model-search-dataset/Tweets_hatred_5_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_hatred_5_trained_model
# Target dataset loaded-     Movie_1
# ../input/model-search-dataset/Financial_News_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Financial_News_2_trained_model
# Target dataset loaded-     Movie_1
# Financial_News_1 --> Movie_1
# Tweets_hatred_5 --> Movie_1
# Financial_News_2 --> Movie_1
# {'Financial_News_1': 1487, 'Tweets_hatred_5': 1668, 'Financial_News_2': 1990}
# TARGET- Tweets_2
# ../input/model-search-dataset/Financial_News_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Financial_News_1_trained_model
# Target dataset loaded-     Tweets_2
# ../input/model-search-dataset/Tweets_hatred_5_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_hatred_5_trained_model
# Target dataset loaded-     Tweets_2
# ../input/model-search-dataset/Financial_News_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Financial_News_2_trained_model
# Target dataset loaded-     Tweets_2
# Financial_News_1 --> Tweets_2
# Tweets_hatred_5 --> Tweets_2
# Financial_News_2 --> Tweets_2
# {'Financial_News_1': 1858, 'Tweets_hatred_5': 1661, 'Financial_News_2': 1779}
# TARGET- Financial_News_2
# ../input/model-search-dataset/Financial_News_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Financial_News_1_trained_model
# Target dataset loaded-     Financial_News_2
# ../input/model-search-dataset/Tweets_hatred_5_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Tweets_hatred_5_trained_model
# Target dataset loaded-     Financial_News_2
# ../input/model-search-dataset/Movie_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_1_trained_model
# Target dataset loaded-     Financial_News_2
# Financial_News_1 --> Financial_News_2
# Tweets_hatred_5 --> Financial_News_2
# Movie_1 --> Financial_News_2
# {'Financial_News_1': 1773, 'Tweets_hatred_5': 1707, 'Movie_1': 1808}
# TARGET- Tweets_hatred_5
# ../input/model-search-dataset/Financial_News_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Financial_News_1_trained_model
# Target dataset loaded-     Tweets_hatred_5
# ../input/model-search-dataset/Financial_News_2_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Financial_News_2_trained_model
# Target dataset loaded-     Tweets_hatred_5
# ../input/model-search-dataset/Movie_1_trained_model
#
# Weights Loaded-       ../input/model-search-dataset/Movie_1_trained_model
# Target dataset loaded-     Tweets_hatred_5
# Financial_News_1 --> Tweets_hatred_5
# Financial_News_2 --> Tweets_hatred_5
# Movie_1 --> Tweets_hatred_5
# {'Financial_News_1': 1905, 'Financial_News_2': 1735, 'Movie_1': 1784}
# {'Tweets_1': {'Financial_News_1': 1872, 'Tweets_hatred_5': 1639, 'Financial_News_2': 1782}, 'Movie_2': {'Financial_News_1': 1508, 'Tweets_hatred_5': 1639, 'Financial_News_2': 1994}, 'Financial_News_1': {'Tweets_hatred_5': 1687, 'Financial_News_2': 1779, 'Movie_1': 1835}, 'Movie_1': {'Financial_News_1': 1487, 'Tweets_hatred_5': 1668, 'Financial_News_2': 1990}, 'Tweets_2': {'Financial_News_1': 1858, 'Tweets_hatred_5': 1661, 'Financial_News_2': 1779}, 'Financial_News_2': {'Financial_News_1': 1773, 'Tweets_hatred_5': 1707, 'Movie_1': 1808}, 'Tweets_hatred_5': {'Financial_News_1': 1905, 'Financial_News_2': 1735, 'Movie_1': 1784}}
# ----##----
# {'JSD': {'Tweets_1': {'Tweets_2': 1426, 'Tweets_hatred_5': 1588, 'Movie_1': 1879}, 'Movie_2': {'Movie_1': 1763, 'Tweets_2': 1892, 'Tweets_1': 1842}, 'Financial_News_1': {'Financial_News_2': 1778, 'Movie_2': 1767, 'Movie_1': 1836}, 'Movie_1': {'Movie_2': 1698, 'Tweets_2': 1882, 'Tweets_1': 1862}, 'Tweets_2': {'Tweets_1': 1558, 'Tweets_hatred_5': 1604, 'Movie_1': 1832}, 'Financial_News_2': {'Financial_News_1': 1740, 'Movie_1': 1841, 'Movie_2': 1785}, 'Tweets_hatred_5': {'Tweets_1': 1868, 'Tweets_2': 1807, 'Movie_1': 1655}}, 'Adaptivity': {'Tweets_1': {'Tweets_2': 1087, 'Tweets_hatred_5': 1927, 'Movie_2': 1984}, 'Movie_2': {'Movie_1': 1763, 'Tweets_1': 1842, 'Tweets_2': 1892}, 'Financial_News_1': {'Movie_1': 1684, 'Tweets_1': 1769, 'Financial_News_2': 1930}, 'Movie_1': {'Movie_2': 1941, 'Tweets_hatred_5': 1271, 'Tweets_1': 1619}, 'Tweets_2': {'Tweets_1': 1240, 'Tweets_hatred_5': 1922, 'Movie_2': 1977}, 'Financial_News_2': {'Movie_1': 1872, 'Tweets_1': 1662, 'Movie_2': 1754}, 'Tweets_hatred_5': {'Tweets_1': 1892, 'Tweets_2': 1783, 'Movie_2': 1532}}, 'L2D': {'Tweets_1': {'Tweets_2': 1426, 'Tweets_hatred_5': 1588, 'Movie_1': 1879}, 'Movie_2': {'Movie_1': 1763, 'Tweets_2': 1892, 'Tweets_1': 1842}, 'Financial_News_1': {'Financial_News_2': 1774, 'Tweets_1': 1925, 'Tweets_2': 1883}, 'Movie_1': {'Movie_2': 1698, 'Tweets_2': 1882, 'Tweets_1': 1862}, 'Tweets_2': {'Tweets_1': 1558, 'Tweets_hatred_5': 1604, 'Movie_1': 1832}, 'Financial_News_2': {'Financial_News_1': 1910, 'Tweets_2': 1880, 'Tweets_1': 1927}, 'Tweets_hatred_5': {'Tweets_1': 1868, 'Tweets_2': 1807, 'Movie_1': 1655}}, 'Source Accuracy': {'Tweets_1': {'Financial_News_1': 1872, 'Tweets_hatred_5': 1639, 'Financial_News_2': 1782}, 'Movie_2': {'Financial_News_1': 1508, 'Tweets_hatred_5': 1639, 'Financial_News_2': 1994}, 'Financial_News_1': {'Tweets_hatred_5': 1687, 'Financial_News_2': 1779, 'Movie_1': 1835}, 'Movie_1': {'Financial_News_1': 1487, 'Tweets_hatred_5': 1668, 'Financial_News_2': 1990}, 'Tweets_2': {'Financial_News_1': 1858, 'Tweets_hatred_5': 1661, 'Financial_News_2': 1779}, 'Financial_News_2': {'Financial_News_1': 1773, 'Tweets_hatred_5': 1707, 'Movie_1': 1808}, 'Tweets_hatred_5': {'Financial_News_1': 1905, 'Financial_News_2': 1735, 'Movie_1': 1784}}}

# %%
import json
    
with open("Max_Voting_Sentiment.json", "w") as outfile:
    json.dump(metric_dic, outfile)
